# %% [markdown]
# # 01 Exploration
#
# Initial data loading and return-distribution exploration for the Wasserstein market regime project.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
sys.path.insert(0, str(ROOT / 'src'))

from regime_ot.data import download_prices
from regime_ot.returns import compute_log_returns, clean_returns
from regime_ot.windows import make_rolling_windows

prices = download_prices(['SPY'], start='2000-01-01')
returns = clean_returns(compute_log_returns(prices['SPY'])).dropna()
windows, dates = make_rolling_windows(returns, window_size=63, step=5)

prices.tail(), returns.describe(), windows.shape
